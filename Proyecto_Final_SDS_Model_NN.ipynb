# %% [markdown]
# # Proyecto Final - Security Data Science
#
# ## Oscar Fernando López Barrios
# ## Carné 20679

# %%
# Importar librerias
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from imblearn.over_sampling import SMOTE
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow as tf

# %%
# Elegir la GPU
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
# Montar Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Asignar el documento con las variables realizadas
df = pd.read_csv('/content/drive/My Drive/SDS/Proyecto-Final-SDS/fraud_detection_dataset.csv')

# %%
# Mostrar dataframe
df
# Out:
#             amt  is_fraud  amt_month_shopping_net_spend  \
# 0          7.27         0                          0.00
# 1         52.94         0                          0.00
# 2         82.08         0                          0.00
# 3         34.79         0                          0.00
# 4         27.18         0                          0.00
# ...         ...       ...                           ...
# 1852389   66.11         0                        160.56
# 1852390    4.58         0                        160.56
# 1852391   95.96         0                        160.56
# 1852392  149.48         0                        160.56
# 1852393   20.55         0                        160.56
#
#          count_month_shopping_net  first_time_at_merchant  hour  minute  \
# 0                             0.0                    True    12      47
# 1                             0.0                    True     8      44
# 2                             0.0                    True     8      47
# 3                             0.0                    True    12      38
# 4                             0.0                    True    13      10
# ...                           ...                     ...   ...     ...
# 1852389                      11.0                   False     2      10
# 1852390                      11.0                   False     5      13
# 1852391                      11.0                   False    11      15
# 1852392                      11.0                   False    11      17
# 1852393                      11.0                   False    13      24
#
#          second  day  month  ...  category_grocery_pos  \
# 0            15    1      1  ...                     0
# 1            57    2      1  ...                     0
# 2            36    2      1  ...                     0
# 3            14    2      1  ...                     0
# 4            46    2      1  ...                     0
# ...         ...  ...    ...  ...                   ...
# 1852389      10   31     12  ...                     0
# 1852390      35   31     12  ...                     0
# 1852391      44   31     12  ...                     0
# 1852392      25   31     12  ...                     1
# 1852393      36   31     12  ...                     0
#
#          category_health_fitness  category_home  category_kids_pets  \
# 0                              0              0                   0
# 1                              0              0                   0
# 2                              0              0                   0
# 3                              0              0                   1
# 4                              0              1                   0
# ...                          ...            ...                 ...
# 1852389                        0              0                   0
# 1852390                        0              0                   0
# 1852391                        0              0                   0
# 1852392                        0              0                   0
# 1852393                        0              0                   1
#
#          category_misc_net  category_misc_pos  category_personal_care  \
# 0                        1                  0                       0
# 1                        0                  0                       0
# 2                        0                  0                       0
# 3                        0                  0                       0
# 4                        0                  0                       0
# ...                    ...                ...                     ...
# 1852389                  0                  0                       0
# 1852390                  1                  0                       0
# 1852391                  0                  0                       0
# 1852392                  0                  0                       0
# 1852393                  0                  0                       0
#
#          category_shopping_net  category_shopping_pos  category_travel
# 0                            0                      0                0
# 1                            0                      0                0
# 2                            0                      0                0
# 3                            0                      0                0
# 4                            0                      0                0
# ...                        ...                    ...              ...
# 1852389                      0                      0                0
# 1852390                      0                      0                0
# 1852391                      0                      0                0
# 1852392                      0                      0                0
# 1852393                      0                      0                0
#
# [1852394 rows x 64 columns]

# %%
# Mostrar los tipos
df.dtypes
# Out:
# amt                             float64
# is_fraud                          int64
# amt_month_shopping_net_spend    float64
# count_month_shopping_net        float64
# first_time_at_merchant             bool
#                                  ...
# category_misc_pos                 int64
# category_personal_care            int64
# category_shopping_net             int64
# category_shopping_pos             int64
# category_travel                   int64
# Length: 64, dtype: object

# %%
# Mostrar el conteo
fraud_counts = df['is_fraud'].value_counts()
print(fraud_counts)
# Out:
# is_fraud
# 0    1842743
# 1       9651
# Name: count, dtype: int64

# %%
# Eliminar los valores nulos
df.fillna(0, inplace=True)

# %%
# Separar características y objetivo
X = df.drop('is_fraud', axis=1)
y = df['is_fraud']

# %%
def train_neural_network(X_train, y_train, X_test, y_test, model=None):
    # Escalar las características para mejorar el rendimiento del modelo
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    # Aplicar SMOTE
    smote = SMOTE(random_state=42)
    X_train_res, y_train_res = smote.fit_resample(X_train_scaled, y_train)

    # Definir el modelo de red neuronal
    if model is None:
        model = Sequential([
            Dense(256, activation='relu', input_shape=(X_train_res.shape[1],)),
            BatchNormalization(),
            Dropout(0.5),
            Dense(128, activation='relu'),
            BatchNormalization(),
            Dropout(0.5),
            Dense(64, activation='relu'),
            BatchNormalization(),
            Dropout(0.5),
            Dense(32, activation='relu'),
            BatchNormalization(),
            Dropout(0.5),
            Dense(1, activation='sigmoid')
        ])
        # Compilar el modelo
        model.compile(optimizer='adam',
                      loss='binary_crossentropy',
                      metrics=['accuracy'])

    # Definir el callback de detención temprana
    early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

    # Entrenar el modelo
    model.fit(X_train_res, y_train_res, epochs=10, batch_size=64, validation_split=0.2, callbacks=[early_stopping])

    # Evaluar el modelo en el conjunto de prueba
    y_pred_proba = model.predict(X_test_scaled)
    y_pred = (y_pred_proba > 0.5).astype(int)

    # Calcular métricas de rendimiento
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    roc_auc = roc_auc_score(y_test, y_pred_proba)
    conf_matrix = confusion_matrix(y_test, y_pred)

    return model, accuracy, precision, recall, f1, roc_auc, conf_matrix

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train_full, X_test, y_train_full, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Variables para almacenar las métricas acumuladas
total_accuracy = 0
total_precision = 0
total_recall = 0
total_f1 = 0
total_roc_auc = 0
confusion_matrices = []

# Contador de períodos
period_count = 0

# Inicializar el modelo
model = None

# Loop para entrenar de manera incremental por cada 3 meses
for year in range(df['year'].min(), df['year'].max() + 1):
    for month in range(1, 13, 3):  # Entrenar cada 3 meses
        # Filtrar los datos para el año y mes actual
        X_train_period = X_train_full[(X_train_full['year'] == year) & (X_train_full['month'].between(month, month + 2))]
        y_train_period = y_train_full[X_train_period.index]

        # Asegurarse de que no hay datos vacíos
        if len(X_train_period) == 0:
            continue

        # Entrenar la red neuronal para este período de tiempo
        print(f"Training for year {year}, month {month}-{month + 2}")
        model, accuracy, precision, recall, f1, roc_auc, conf_matrix = train_neural_network(X_train_period, y_train_period, X_test, y_test, model)

        # Acumular métricas
        total_accuracy += accuracy
        total_precision += precision
        total_recall += recall
        total_f1 += f1
        total_roc_auc += roc_auc
        confusion_matrices.append(conf_matrix)

        # Incrementar el contador de períodos
        period_count += 1

        # Imprimir métricas para este período
        print(f"Accuracy: {accuracy:.4f}")
        print(f"Precision: {precision:.4f}")
        print(f"Recall: {recall:.4f}")
        print(f"F1 Score: {f1:.4f}")
        print(f"ROC AUC Score: {roc_auc:.4f}")
        print(f"Confusion Matrix:\n{conf_matrix}")

# Calcular las métricas finales promedio
final_accuracy = total_accuracy / period_count
final_precision = total_precision / period_count
final_recall = total_recall / period_count
final_f1 = total_f1 / period_count
final_roc_auc = total_roc_auc / period_count

# Sumar las matrices de confusión
final_confusion_matrix = np.sum(confusion_matrices, axis=0)

# Imprimir las métricas finales
print("\nFinal Metrics:")
print(f"Accuracy: {final_accuracy:.4f}")
print(f"Precision: {final_precision:.4f}")
print(f"Recall: {final_recall:.4f}")
print(f"F1 Score: {final_f1:.4f}")
print(f"ROC AUC Score: {final_roc_auc:.4f}")
print(f"Confusion Matrix:\n{final_confusion_matrix}")
# Out:
# Training for year 2019, month 1-3
# Epoch 1/10
# 3004/3004 [==============================] - 33s 9ms/step - loss: 0.0854 - accuracy: 0.9709 - val_loss: 0.0064 - val_accuracy: 0.9988
# Epoch 2/10
# 3004/3004 [==============================] - 25s 8ms/step - loss: 0.0333 - accuracy: 0.9906 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 3/10
# 3004/3004 [==============================] - 26s 8ms/step - loss: 0.0247 - accuracy: 0.9931 - val_loss: 9.1808e-04 - val_accuracy: 0.9999
# Epoch 4/10
# 3004/3004 [==============================] - 26s 9ms/step - loss: 0.0193 - accuracy: 0.9948 - val_loss: 0.0010 - val_accuracy: 0.9998
# Epoch 5/10
# 3004/3004 [==============================] - 25s 8ms/step - loss: 0.0156 - accuracy: 0.9957 - val_loss: 7.4884e-04 - val_accuracy: 0.9999
# Epoch 6/10
# 3004/3004 [==============================] - 24s 8ms/step - loss: 0.0124 - accuracy: 0.9969 - val_loss: 3.1991e-04 - val_accuracy: 1.0000
# Epoch 7/10
# 3004/3004 [==============================] - 24s 8ms/step - loss: 0.0105 - accuracy: 0.9972 - val_loss: 3.1386e-04 - val_accuracy: 0.9999
# Epoch 8/10
# 3004/3004 [==============================] - 25s 8ms/step - loss: 0.0111 - accuracy: 0.9970 - val_loss: 1.4958e-04 - val_accuracy: 1.0000
# Epoch 9/10
# 3004/3004 [==============================] - 24s 8ms/step - loss: 0.0093 - accuracy: 0.9977 - val_loss: 1.9918e-04 - val_accuracy: 1.0000
# Epoch 10/10
# 3004/3004 [==============================] - 25s 8ms/step - loss: 0.0084 - accuracy: 0.9978 - val_loss: 3.7474e-05 - val_accuracy: 1.0000
# 17367/17367 [==============================] - 37s 2ms/step
# Accuracy: 0.9963
# Precision: 0.9102
# Recall: 0.3096
# F1 Score: 0.4620
# ROC AUC Score: 0.7322
# Confusion Matrix:
# [[552783     87]
#  [  1967    882]]
# Training for year 2019, month 4-6
# Epoch 1/10
# 3955/3955 [==============================] - 33s 8ms/step - loss: 0.0172 - accuracy: 0.9956 - val_loss: 7.8420e-04 - val_accuracy: 0.9999
# Epoch 2/10
# 3955/3955 [==============================] - 32s 8ms/step - loss: 0.0098 - accuracy: 0.9975 - val_loss: 2.0690e-04 - val_accuracy: 1.0000
# Epoch 3/10
# 3955/3955 [==============================] - 32s 8ms/step - loss: 0.0073 - accuracy: 0.9980 - val_loss: 1.9694e-04 - val_accuracy: 1.0000
# Epoch 4/10
# 3955/3955 [==============================] - 35s 9ms/step - loss: 0.0068 - accuracy: 0.9983 - val_loss: 2.4241e-04 - val_accuracy: 1.0000
# Epoch 5/10
# 3955/3955 [==============================] - 32s 8ms/step - loss: 0.0062 - accuracy: 0.9985 - val_loss: 6.8542e-05 - val_accuracy: 1.0000
# Epoch 6/10
# 3955/3955 [==============================] - 32s 8ms/step - loss: 0.0053 - accuracy: 0.9987 - val_loss: 1.8902e-05 - val_accuracy: 1.0000
# Epoch 7/10
# 3955/3955 [==============================] - 35s 9ms/step - loss: 0.0054 - accuracy: 0.9987 - val_loss: 1.3459e-04 - val_accuracy: 1.0000
# Epoch 8/10
# 3955/3955 [==============================] - 32s 8ms/step - loss: 0.0046 - accuracy: 0.9989 - val_loss: 1.6017e-04 - val_accuracy: 1.0000
# Epoch 9/10
# 3955/3955 [==============================] - 32s 8ms/step - loss: 0.0047 - accuracy: 0.9988 - val_loss: 8.6384e-05 - val_accuracy: 1.0000
# 17367/17367 [==============================] - 36s 2ms/step
# Accuracy: 0.9974
# Precision: 0.9076
# Recall: 0.5553
# F1 Score: 0.6890
# ROC AUC Score: 0.8877
# Confusion Matrix:
# [[552709    161]
#  [  1267   1582]]
# Training for year 2019, month 7-9
# Epoch 1/10
# 4254/4254 [==============================] - 34s 8ms/step - loss: 0.0193 - accuracy: 0.9949 - val_loss: 6.1050e-04 - val_accuracy: 1.0000
# Epoch 2/10
# 4254/4254 [==============================] - 35s 8ms/step - loss: 0.0096 - accuracy: 0.9975 - val_loss: 4.8394e-04 - val_accuracy: 1.0000
# Epoch 3/10
# 4254/4254 [==============================] - 35s 8ms/step - loss: 0.0079 - accuracy: 0.9980 - val_loss: 2.5298e-04 - val_accuracy: 1.0000
# Epoch 4/10
# 4254/4254 [==============================] - 38s 9ms/step - loss: 0.0066 - accuracy: 0.9983 - val_loss: 2.2631e-04 - val_accuracy: 1.0000
# Epoch 5/10
# 4254/4254 [==============================] - 35s 8ms/step - loss: 0.0061 - accuracy: 0.9986 - val_loss: 1.5442e-04 - val_accuracy: 1.0000
# Epoch 6/10
# 4254/4254 [==============================] - 35s 8ms/step - loss: 0.0050 - accuracy: 0.9988 - val_loss: 8.1670e-04 - val_accuracy: 0.9998
# Epoch 7/10
# 4254/4254 [==============================] - 34s 8ms/step - loss: 0.0051 - accuracy: 0.9987 - val_loss: 6.9544e-05 - val_accuracy: 1.0000
# Epoch 8/10
# 4254/4254 [==============================] - 35s 8ms/step - loss: 0.0047 - accuracy: 0.9988 - val_loss: 1.2449e-05 - val_accuracy: 1.0000
# Epoch 9/10
# 4254/4254 [==============================] - 34s 8ms/step - loss: 0.0045 - accuracy: 0.9989 - val_loss: 1.7224e-05 - val_accuracy: 1.0000
# Epoch 10/10
# 4254/4254 [==============================] - 37s 9ms/step - loss: 0.0043 - accuracy: 0.9990 - val_loss: 6.1431e-05 - val_accuracy: 1.0000
# 17367/17367 [==============================] - 35s 2ms/step
# Accuracy: 0.9977
# Precision: 0.9549
# Recall: 0.5792
# F1 Score: 0.7210
# ROC AUC Score: 0.9263
# Confusion Matrix:
# [[552792     78]
#  [  1199   1650]]
# Training for year 2019, month 10-12
# Epoch 1/10
# 4877/4877 [==============================] - 40s 8ms/step - loss: 0.0127 - accuracy: 0.9969 - val_loss: 2.4459e-04 - val_accuracy: 1.0000
# Epoch 2/10
# 4877/4877 [==============================] - 42s 9ms/step - loss: 0.0063 - accuracy: 0.9984 - val_loss: 4.8846e-04 - val_accuracy: 1.0000
# Epoch 3/10
# 4877/4877 [==============================] - 42s 9ms/step - loss: 0.0053 - accuracy: 0.9987 - val_loss: 7.4666e-05 - val_accuracy: 1.0000
# Epoch 4/10
# 4877/4877 [==============================] - 41s 8ms/step - loss: 0.0045 - accuracy: 0.9989 - val_loss: 9.5268e-05 - val_accuracy: 1.0000
# Epoch 5/10
# 4877/4877 [==============================] - 39s 8ms/step - loss: 0.0044 - accuracy: 0.9989 - val_loss: 3.9591e-04 - val_accuracy: 0.9999
# Epoch 6/10
# 4877/4877 [==============================] - 39s 8ms/step - loss: 0.0043 - accuracy: 0.9990 - val_loss: 8.2163e-05 - val_accuracy: 1.0000
# 17367/17367 [==============================] - 36s 2ms/step
# Accuracy: 0.9977
# Precision: 0.9294
# Recall: 0.5911
# F1 Score: 0.7226
# ROC AUC Score: 0.9597
# Confusion Matrix:
# [[552742    128]
#  [  1165   1684]]
# Training for year 2020, month 1-3
# Epoch 1/10
# 3015/3015 [==============================] - 25s 8ms/step - loss: 0.0171 - accuracy: 0.9958 - val_loss: 4.7977e-04 - val_accuracy: 0.9999
# Epoch 2/10
# 3015/3015 [==============================] - 24s 8ms/step - loss: 0.0061 - accuracy: 0.9984 - val_loss: 8.8341e-05 - val_accuracy: 1.0000
# Epoch 3/10
# 3015/3015 [==============================] - 25s 8ms/step - loss: 0.0042 - accuracy: 0.9990 - val_loss: 1.2617e-04 - val_accuracy: 1.0000
# Epoch 4/10
# 3015/3015 [==============================] - 25s 8ms/step - loss: 0.0034 - accuracy: 0.9991 - val_loss: 1.0557e-04 - val_accuracy: 1.0000
# Epoch 5/10
# 3015/3015 [==============================] - 25s 8ms/step - loss: 0.0036 - accuracy: 0.9991 - val_loss: 2.4533e-05 - val_accuracy: 1.0000
# Epoch 6/10
# 3015/3015 [==============================] - 25s 8ms/step - loss: 0.0030 - accuracy: 0.9992 - val_loss: 1.0845e-05 - val_accuracy: 1.0000
# Epoch 7/10
# 3015/3015 [==============================] - 25s 8ms/step - loss: 0.0032 - accuracy: 0.9993 - val_loss: 4.4311e-06 - val_accuracy: 1.0000
# Epoch 8/10
# 3015/3015 [==============================] - 25s 8ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 4.1458e-06 - val_accuracy: 1.0000
# Epoch 9/10
# 3015/3015 [==============================] - 25s 8ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 1.1419e-06 - val_accuracy: 1.0000
# Epoch 10/10
# 3015/3015 [==============================] - 26s 9ms/step - loss: 0.0027 - accuracy: 0.9994 - val_loss: 2.2307e-06 - val_accuracy: 1.0000
# 17367/17367 [==============================] - 38s 2ms/step
# Accuracy: 0.9974
# Precision: 0.8549
# Recall: 0.6041
# F1 Score: 0.7079
# ROC AUC Score: 0.9414
# Confusion Matrix:
# [[552578    292]
#  [  1128   1721]]
# Training for year 2020, month 4-6
# Epoch 1/10
# 3992/3992 [==============================] - 33s 8ms/step - loss: 0.0120 - accuracy: 0.9969 - val_loss: 6.6300e-04 - val_accuracy: 0.9999
# Epoch 2/10
# 3992/3992 [==============================] - 32s 8ms/step - loss: 0.0056 - accuracy: 0.9986 - val_loss: 1.0982e-04 - val_accuracy: 1.0000
# Epoch 3/10
# 3992/3992 [==============================] - 33s 8ms/step - loss: 0.0054 - accuracy: 0.9987 - val_loss: 1.4170e-04 - val_accuracy: 1.0000
# Epoch 4/10
# 3992/3992 [==============================] - 34s 8ms/step - loss: 0.0039 - accuracy: 0.9990 - val_loss: 8.0714e-05 - val_accuracy: 1.0000
# Epoch 5/10
# 3992/3992 [==============================] - 33s 8ms/step - loss: 0.0039 - accuracy: 0.9991 - val_loss: 5.1328e-05 - val_accuracy: 1.0000
# Epoch 6/10
# 3992/3992 [==============================] - 33s 8ms/step - loss: 0.0034 - accuracy: 0.9992 - val_loss: 8.0738e-05 - val_accuracy: 1.0000
# Epoch 7/10
# 3992/3992 [==============================] - 36s 9ms/step - loss: 0.0033 - accuracy: 0.9991 - val_loss: 9.6976e-05 - val_accuracy: 1.0000
# Epoch 8/10
# 3992/3992 [==============================] - 33s 8ms/step - loss: 0.0031 - accuracy: 0.9992 - val_loss: 8.1480e-05 - val_accuracy: 1.0000
# 17367/17367 [==============================] - 36s 2ms/step
# Accuracy: 0.9983
# Precision: 0.8716
# Recall: 0.7908
# F1 Score: 0.8292
# ROC AUC Score: 0.9881
# Confusion Matrix:
# [[552538    332]
#  [   596   2253]]
# Training for year 2020, month 7-9
# Epoch 1/10
# 4247/4247 [==============================] - 35s 8ms/step - loss: 0.0144 - accuracy: 0.9960 - val_loss: 0.0010 - val_accuracy: 0.9998
# Epoch 2/10
# 4247/4247 [==============================] - 36s 8ms/step - loss: 0.0064 - accuracy: 0.9983 - val_loss: 3.3546e-04 - val_accuracy: 0.9999
# Epoch 3/10
# 4247/4247 [==============================] - 35s 8ms/step - loss: 0.0052 - accuracy: 0.9987 - val_loss: 6.4999e-05 - val_accuracy: 1.0000
# Epoch 4/10
# 4247/4247 [==============================] - 35s 8ms/step - loss: 0.0042 - accuracy: 0.9990 - val_loss: 7.3166e-05 - val_accuracy: 1.0000
# Epoch 5/10
# 4247/4247 [==============================] - 35s 8ms/step - loss: 0.0042 - accuracy: 0.9990 - val_loss: 2.7318e-05 - val_accuracy: 1.0000
# Epoch 6/10
# 4247/4247 [==============================] - 37s 9ms/step - loss: 0.0034 - accuracy: 0.9992 - val_loss: 9.6390e-06 - val_accuracy: 1.0000
# Epoch 7/10
# 4247/4247 [==============================] - 35s 8ms/step - loss: 0.0034 - accuracy: 0.9991 - val_loss: 2.8070e-05 - val_accuracy: 1.0000
# Epoch 8/10
# 4247/4247 [==============================] - 38s 9ms/step - loss: 0.0037 - accuracy: 0.9992 - val_loss: 2.2049e-05 - val_accuracy: 1.0000
# Epoch 9/10
# 4247/4247 [==============================] - 34s 8ms/step - loss: 0.0033 - accuracy: 0.9992 - val_loss: 6.3246e-06 - val_accuracy: 1.0000
# Epoch 10/10
# 4247/4247 [==============================] - 36s 8ms/step - loss: 0.0026 - accuracy: 0.9994 - val_loss: 9.2129e-06 - val_accuracy: 1.0000
# 17367/17367 [==============================] - 38s 2ms/step
# Accuracy: 0.9982
# Precision: 0.8726
# Recall: 0.7669
# F1 Score: 0.8164
# ROC AUC Score: 0.9821
# Confusion Matrix:
# [[552551    319]
#  [   664   2185]]
# Training for year 2020, month 10-12
# Epoch 1/10
# 4907/4907 [==============================] - 43s 9ms/step - loss: 0.0114 - accuracy: 0.9971 - val_loss: 5.2557e-04 - val_accuracy: 0.9999
# Epoch 2/10
# 4907/4907 [==============================] - 40s 8ms/step - loss: 0.0051 - accuracy: 0.9988 - val_loss: 2.4151e-04 - val_accuracy: 0.9999
# Epoch 3/10
# 4907/4907 [==============================] - 40s 8ms/step - loss: 0.0037 - accuracy: 0.9991 - val_loss: 2.3082e-05 - val_accuracy: 1.0000
# Epoch 4/10
# 4907/4907 [==============================] - 41s 8ms/step - loss: 0.0030 - accuracy: 0.9993 - val_loss: 1.1789e-04 - val_accuracy: 1.0000
# Epoch 5/10
# 4907/4907 [==============================] - 39s 8ms/step - loss: 0.0028 - accuracy: 0.9993 - val_loss: 3.1628e-05 - val_accuracy: 1.0000
# Epoch 6/10
# 4907/4907 [==============================] - 40s 8ms/step - loss: 0.0027 - accuracy: 0.9994 - val_loss: 1.6912e-05 - val_accuracy: 1.0000
# Epoch 7/10
# 4907/4907 [==============================] - 40s 8ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 1.7117e-04 - val_accuracy: 1.0000
# Epoch 8/10
# 4907/4907 [==============================] - 40s 8ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 5.1541e-06 - val_accuracy: 1.0000
# Epoch 9/10
# 4907/4907 [==============================] - 41s 8ms/step - loss: 0.0021 - accuracy: 0.9995 - val_loss: 5.1123e-05 - val_accuracy: 1.0000
# Epoch 10/10
# 4907/4907 [==============================] - 41s 8ms/step - loss: 0.0021 - accuracy: 0.9995 - val_loss: 6.0627e-05 - val_accuracy: 1.0000
# 17367/17367 [==============================] - 36s 2ms/step
# Accuracy: 0.9970
# Precision: 0.7530
# Recall: 0.6079
# F1 Score: 0.6728
# ROC AUC Score: 0.9568
# Confusion Matrix:
# [[552302    568]
#  [  1117   1732]]
#
# Final Metrics:
# Accuracy: 0.9975
# Precision: 0.8818
# Recall: 0.6006
# F1 Score: 0.7026
# ROC AUC Score: 0.9218
# Confusion Matrix:
# [[4420995    1965]
#  [   9103   13689]]
